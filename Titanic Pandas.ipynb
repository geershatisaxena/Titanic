# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sys
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### **Load and Basic Info**

# %%
df = sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#  Show first 5 rows
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Show last 5 rows
df.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
#  Check dataset shape
df.shape
# Out:
# (891, 15)

# %%
#  Get column names
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#  Check data types
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
#  Basic stats
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#  Info summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#  Count null values
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#  Show unique values in 'sex'
df['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# #### Selection and Filtering

# %%
#  Select 'age' column
df['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
#  Select multiple columns
df[['age', 'sex', 'fare']]
# Out:
#       age     sex     fare
# 0    22.0    male   7.2500
# 1    38.0  female  71.2833
# 2    26.0  female   7.9250
# 3    35.0  female  53.1000
# 4    35.0    male   8.0500
# ..    ...     ...      ...
# 886  27.0    male  13.0000
# 887  19.0  female  30.0000
# 888   NaN  female  23.4500
# 889  26.0    male  30.0000
# 890  32.0    male   7.7500
#
# [891 rows x 3 columns]

# %%
# 13. Filter males only
df[df['sex'] == 'male']
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [577 rows x 15 columns]

# %%
# 14. Filter females only
df[df['sex'] == 'female']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [314 rows x 15 columns]

# %%
# 15. Age above 60
df[df['age'] > 60]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 33          0       2    male  66.0      0      0   10.5000        S  Second
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 96          0       1    male  71.0      0      0   34.6542        C   First
# 116         0       3    male  70.5      0      0    7.7500        Q   Third
# 170         0       1    male  61.0      0      0   33.5000        S   First
# 252         0       1    male  62.0      0      0   26.5500        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 280         0       3    male  65.0      0      0    7.7500        Q   Third
# 326         0       3    male  61.0      0      0    6.2375        S   Third
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 456         0       1    male  65.0      0      0   26.5500        S   First
# 483         1       3  female  63.0      0      0    9.5875        S   Third
# 493         0       1    male  71.0      0      0   49.5042        C   First
# 545         0       1    male  64.0      0      0   26.0000        S   First
# 555         0       1    male  62.0      0      0   26.5500        S   First
# 570         1       2    male  62.0      0      0   10.5000        S  Second
# 625         0       1    male  61.0      0      0   32.3208        S   First
# 630         1       1    male  80.0      0      0   30.0000        S   First
# 672         0       2    male  70.0      0      0   10.5000        S  Second
# 745         0       1    male  70.0      1      1   71.0000        S   First
# 829         1       1  female  62.0      0      0   80.0000      NaN   First
# 851         0       3    male  74.0      0      0    7.7750        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 33     man        True  NaN  Southampton    no   True
# 54     man        True    B    Cherbourg    no  False
# 96     man        True    A    Cherbourg    no   True
# 116    man        True  NaN   Queenstown    no   True
# 170    man        True    B  Southampton    no   True
# 252    man        True    C  Southampton    no   True
# 275  woman       False    D  Southampton   yes  False
# 280    man        True  NaN   Queenstown    no   True
# 326    man        True  NaN  Southampton    no   True
# 438    man        True    C  Southampton    no  False
# 456    man        True    E  Southampton    no   True
# 483  woman       False  NaN  Southampton   yes   True
# 493    man        True  NaN    Cherbourg    no   True
# 545    man        True  NaN  Southampton    no   True
# 555    man        True  NaN  Southampton    no   True
# 570    man        True  NaN  Southampton   yes   True
# 625    man        True    D  Southampton    no   True
# 630    man        True    A  Southampton   yes   True
# 672    man        True  NaN  Southampton    no   True
# 745    man        True    B  Southampton    no  False
# 829  woman       False    B          NaN   yes   True
# 851    man        True  NaN  Southampton    no   True

# %%
# 16. Survived passengers
df[df['survived'] == 1]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 9    child       False  NaN    Cherbourg   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 875  child       False  NaN    Cherbourg   yes   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [342 rows x 15 columns]

# %%
# 17. Did not survive
df[df['survived'] == 0]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 4      man        True  NaN  Southampton    no   True
# 5      man        True  NaN   Queenstown    no   True
# 6      man        True    E  Southampton    no   True
# 7    child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 884    man        True  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 886    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
# 890    man        True  NaN   Queenstown    no   True
#
# [549 rows x 15 columns]

# %%
#  Non-null deck values
df[df['deck'].notnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [203 rows x 15 columns]

# %%
df.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
# Null age values
df[df['age'].isnull()]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 5      man        True  NaN   Queenstown    no   True
# 17     man        True  NaN  Southampton   yes   True
# 19   woman       False  NaN    Cherbourg   yes   True
# 26     man        True  NaN    Cherbourg    no   True
# 28   woman       False  NaN   Queenstown   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 859    man        True  NaN    Cherbourg    no   True
# 863  woman       False  NaN  Southampton    no  False
# 868    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
#
# [177 rows x 15 columns]

# %% [markdown]
# #### Sorting & Indexing

# %%
#  Sort by age
df.sort_values(by='age')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 803         1       3    male  0.42      0      1   8.5167        C   Third
# 755         1       2    male  0.67      1      1  14.5000        S  Second
# 644         1       3  female  0.75      2      1  19.2583        C   Third
# 469         1       3  female  0.75      2      1  19.2583        C   Third
# 78          1       2    male  0.83      0      2  29.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 859         0       3    male   NaN      0      0   7.2292        C   Third
# 863         0       3  female   NaN      8      2  69.5500        S   Third
# 868         0       3    male   NaN      0      0   9.5000        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 78   child       False  NaN  Southampton   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 859    man        True  NaN    Cherbourg    no   True
# 863  woman       False  NaN  Southampton    no  False
# 868    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
#
# [891 rows x 15 columns]

# %%
#  Sort by fare descending
df.sort_values(by='fare', ascending=False)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 258         1       1  female  35.0      0      0  512.3292        C   First
# 737         1       1    male  35.0      0      0  512.3292        C   First
# 679         1       1    male  36.0      0      1  512.3292        C   First
# 88          1       1  female  23.0      3      2  263.0000        S   First
# 27          0       1    male  19.0      3      2  263.0000        S   First
# ..        ...     ...     ...   ...    ...    ...       ...      ...     ...
# 633         0       1    male   NaN      0      0    0.0000        S   First
# 413         0       2    male   NaN      0      0    0.0000        S  Second
# 822         0       1    male  38.0      0      0    0.0000        S   First
# 732         0       2    male   NaN      0      0    0.0000        S  Second
# 674         0       2    male   NaN      0      0    0.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# 737    man        True    B    Cherbourg   yes   True
# 679    man        True    B    Cherbourg   yes  False
# 88   woman       False    C  Southampton   yes  False
# 27     man        True    C  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 633    man        True  NaN  Southampton    no   True
# 413    man        True  NaN  Southampton    no   True
# 822    man        True  NaN  Southampton    no   True
# 732    man        True  NaN  Southampton    no   True
# 674    man        True  NaN  Southampton    no   True
#
# [891 rows x 15 columns]

# %%
#  Reset index
df.reset_index(drop=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#  Set 'embarked' as index
df.set_index('embarked')
# Out:
#           survived  pclass     sex   age  sibsp  parch     fare   class  \
# embarked
# S                0       3    male  22.0      1      0   7.2500   Third
# C                1       1  female  38.0      1      0  71.2833   First
# S                1       3  female  26.0      0      0   7.9250   Third
# S                1       1  female  35.0      1      0  53.1000   First
# S                0       3    male  35.0      0      0   8.0500   Third
# ...            ...     ...     ...   ...    ...    ...      ...     ...
# S                0       2    male  27.0      0      0  13.0000  Second
# S                1       1  female  19.0      0      0  30.0000   First
# S                0       3  female   NaN      1      2  23.4500   Third
# C                1       1    male  26.0      0      0  30.0000   First
# Q                0       3    male  32.0      0      0   7.7500   Third
#
#             who  adult_male deck  embark_town alive  alone
# embarked
# S           man        True  NaN  Southampton    no  False
# C         woman       False    C    Cherbourg   yes  False
# S         woman       False  NaN  Southampton   yes   True
# S         woman       False    C  Southampton   yes  False
# S           man        True  NaN  Southampton    no   True
# ...         ...         ...  ...          ...   ...    ...
# S           man        True  NaN  Southampton    no   True
# S         woman       False    B  Southampton   yes   True
# S         woman       False  NaN  Southampton    no  False
# C           man        True    C    Cherbourg   yes   True
# Q           man        True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
#  Sort by 'class' then 'age'
df.sort_values(by=['class', 'age'])
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 305         1       1    male   0.92      1      2  151.5500        S  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 445         1       1    male   4.00      0      2   81.8583        S  First
# 802         1       1    male  11.00      1      2  120.0000        S  First
# 435         1       1  female  14.00      1      2  120.0000        S  First
# ..        ...     ...     ...    ...    ...    ...       ...      ...    ...
# 859         0       3    male    NaN      0      0    7.2292        C  Third
# 863         0       3  female    NaN      8      2   69.5500        S  Third
# 868         0       3    male    NaN      0      0    9.5000        S  Third
# 878         0       3    male    NaN      0      0    7.8958        S  Third
# 888         0       3  female    NaN      1      2   23.4500        S  Third
#
#        who  adult_male deck  embark_town alive  alone
# 305  child       False    C  Southampton   yes  False
# 297  child       False    C  Southampton    no  False
# 445  child       False    A  Southampton   yes  False
# 802  child       False    B  Southampton   yes  False
# 435  child       False    B  Southampton   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 859    man        True  NaN    Cherbourg    no   True
# 863  woman       False  NaN  Southampton    no  False
# 868    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 888  woman       False  NaN  Southampton    no  False
#
# [891 rows x 15 columns]

# %%
# Select rows by iloc (0–4)
df.iloc[0:5]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Select by loc - row 0, column 'age'
df.loc[0, 'age']
# Out:
# 22.0

# %%
#  Get every 5th row
df.iloc[::5]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 20          0       2    male  35.0      0      0  26.0000        S  Second
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 5      man        True  NaN   Queenstown    no   True
# 10   child       False    G  Southampton   yes  False
# 15   woman       False  NaN  Southampton   yes   True
# 20     man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 870    man        True  NaN  Southampton    no   True
# 875  child       False  NaN    Cherbourg   yes   True
# 880  woman       False  NaN  Southampton   yes  False
# 885  woman       False  NaN   Queenstown    no  False
# 890    man        True  NaN   Queenstown    no   True
#
# [179 rows x 15 columns]

# %%
#  Top 10 youngest
df.nsmallest(10, 'age')
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 831         1       2    male  0.83      1      1   18.7500        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 164         0       3    male  1.00      4      1   39.6875        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 803  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 78   child       False  NaN  Southampton   yes  False
# 831  child       False  NaN  Southampton   yes  False
# 305  child       False    C  Southampton   yes  False
# 164  child       False  NaN  Southampton    no  False
# 172  child       False  NaN  Southampton   yes  False
# 183  child       False    F  Southampton   yes  False

# %%
#  Top 10 oldest
df.nlargest(10, 'age')
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 630         1       1  male  80.0      0      0  30.0000        S   First
# 851         0       3  male  74.0      0      0   7.7750        S   Third
# 96          0       1  male  71.0      0      0  34.6542        C   First
# 493         0       1  male  71.0      0      0  49.5042        C   First
# 116         0       3  male  70.5      0      0   7.7500        Q   Third
# 672         0       2  male  70.0      0      0  10.5000        S  Second
# 745         0       1  male  70.0      1      1  71.0000        S   First
# 33          0       2  male  66.0      0      0  10.5000        S  Second
# 54          0       1  male  65.0      0      1  61.9792        C   First
# 280         0       3  male  65.0      0      0   7.7500        Q   Third
#
#      who  adult_male deck  embark_town alive  alone
# 630  man        True    A  Southampton   yes   True
# 851  man        True  NaN  Southampton    no   True
# 96   man        True    A    Cherbourg    no   True
# 493  man        True  NaN    Cherbourg    no   True
# 116  man        True  NaN   Queenstown    no   True
# 672  man        True  NaN  Southampton    no   True
# 745  man        True    B  Southampton    no  False
# 33   man        True  NaN  Southampton    no   True
# 54   man        True    B    Cherbourg    no  False
# 280  man        True  NaN   Queenstown    no   True

# %% [markdown]
# #### Missing Value Handling

# %%
# Fill age with median
df['age'].fillna(df['age'].median(), inplace=True)

# %%
#  Fill embarked with mode
df['embarked'].fillna(df['embarked'].mode()[0], inplace=True)

# %%
#  Drop all rows with any nulls
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [201 rows x 15 columns]

# %%
#  Drop column with many nulls
df.drop(columns='deck')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# 0      man        True  Southampton    no  False
# 1    woman       False    Cherbourg   yes  False
# 2    woman       False  Southampton   yes   True
# 3    woman       False  Southampton   yes  False
# 4      man        True  Southampton    no   True
# ..     ...         ...          ...   ...    ...
# 886    man        True  Southampton    no   True
# 887  woman       False  Southampton   yes   True
# 888  woman       False  Southampton    no  False
# 889    man        True    Cherbourg   yes   True
# 890    man        True   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
# Fill embark_town with 'Unknown'
df['embark_town'].fillna('Unknown', inplace=True)

# %%
#  Fill embarked with 'S'
df['embarked'].fillna('S', inplace=True)

# %%
# 37. Check how many NaNs
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
#  Drop rows where age is null
df[df['age'].notnull()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
#  Replace NaNs in 'embark_town' with 'Unknown'
df['embark_town'].fillna('Unknown', inplace=True)

# %%
#  Fill age with mean
df['age'].fillna(df['age'].mean())
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# #### GroupBy & Aggregation

# %%
#  Group by sex and get mean age
df.groupby('sex')['age'].mean()
# Out:
# sex
# female    27.929936
# male      30.140676
# Name: age, dtype: float64

# %%
#  Group by class and fare mean
df.groupby('class')['fare'].mean()
# Out:
# class
# First     84.154687
# Second    20.662183
# Third     13.675550
# Name: fare, dtype: float64

# %%
#  Survived count by class
df.groupby('class')['survived'].sum()
# Out:
# class
# First     136
# Second     87
# Third     119
# Name: survived, dtype: int64

# %%
#  Count passengers per class
df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
#  Average fare by sex
df.groupby('sex')['fare'].mean()
# Out:
# sex
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64

# %%
# Median age by class
df.groupby('class')['age'].median()
# Out:
# class
# First     35.0
# Second    28.0
# Third     28.0
# Name: age, dtype: float64

# %%
#  Groupby sex and survived
df.groupby(['sex', 'survived'])['age'].count()
# Out:
# sex     survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: age, dtype: int64

# %%
#  Pivot: class vs survived
df.pivot_table(index='class', columns='survived', values='age', aggfunc='mean')
# Out:
# survived          0          1
# class
# First     40.556250  34.609706
# Second    33.144330  25.998046
# Third     26.951613  22.747227

# %%
# 49. Average age by class and sex
df.groupby(['class', 'sex'])['age'].mean()
# Out:
# class   sex
# First   female    33.978723
#         male      38.995246
# Second  female    28.703947
#         male      30.512315
# Third   female    23.572917
#         male      26.911873
# Name: age, dtype: float64

# %%
# Grouped size
df.groupby('embarked').size()
# Out:
# embarked
# C    168
# Q     77
# S    646
# dtype: int64

# %% [markdown]
# #### New Columns & Transform

# %%
#  Create child column (age < 12)
df['is_child'] = df['age'] < 12

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  is_child
# 0    man        True  NaN  Southampton    no  False     False
# 1  woman       False    C    Cherbourg   yes  False     False
# 2  woman       False  NaN  Southampton   yes   True     False
# 3  woman       False    C  Southampton   yes  False     False
# 4    man        True  NaN  Southampton    no   True     False

# %%
#  Create elderly column (age > 60)
df['is_elderly'] = df['age'] > 60

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  is_child  is_elderly
# 0    man        True  NaN  Southampton    no  False     False       False
# 1  woman       False    C    Cherbourg   yes  False     False       False
# 2  woman       False  NaN  Southampton   yes   True     False       False
# 3  woman       False    C  Southampton   yes  False     False       False
# 4    man        True  NaN  Southampton    no   True     False       False

# %%
# Age bucket column
df['age_group'] = pd.cut(df['age'], bins=[0, 12, 18, 60, 100], labels=['Child', 'Teen', 'Adult', 'Senior'])

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  is_child  is_elderly  \
# 0    man        True  NaN  Southampton    no  False     False       False
# 1  woman       False    C    Cherbourg   yes  False     False       False
# 2  woman       False  NaN  Southampton   yes   True     False       False
# 3  woman       False    C  Southampton   yes  False     False       False
# 4    man        True  NaN  Southampton    no   True     False       False
#
#   age_group
# 0     Adult
# 1     Adult
# 2     Adult
# 3     Adult
# 4     Adult

# %%
#  Fare per person (if sibsp + parch > 0)
df['total_people'] = df['sibsp'] + df['parch'] + 1
df['fare_per_person'] = df['fare'] / df['total_people']

# %%
#  Sex encoded
df['sex_encoded'] = df['sex'].map({'male': 0, 'female': 1})

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  ...  deck  embark_town alive  alone  is_child  is_elderly  \
# 0    man  ...   NaN  Southampton    no  False     False       False
# 1  woman  ...     C    Cherbourg   yes  False     False       False
# 2  woman  ...   NaN  Southampton   yes   True     False       False
# 3  woman  ...     C  Southampton   yes  False     False       False
# 4    man  ...   NaN  Southampton    no   True     False       False
#
#    age_group total_people  fare_per_person  sex_encoded
# 0      Adult            2          3.62500            0
# 1      Adult            2         35.64165            1
# 2      Adult            1          7.92500            1
# 3      Adult            2         26.55000            1
# 4      Adult            1          8.05000            0
#
# [5 rows x 21 columns]

# %%
#  Class numeric
df['class_num'] = df['class'].map({'First': 1, 'Second': 2, 'Third': 3})

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  ...  embark_town alive  alone is_child  is_elderly  age_group  \
# 0    man  ...  Southampton    no  False    False       False      Adult
# 1  woman  ...    Cherbourg   yes  False    False       False      Adult
# 2  woman  ...  Southampton   yes   True    False       False      Adult
# 3  woman  ...  Southampton   yes  False    False       False      Adult
# 4    man  ...  Southampton    no   True    False       False      Adult
#
#    total_people fare_per_person  sex_encoded  class_num
# 0             2         3.62500            0          3
# 1             2        35.64165            1          1
# 2             1         7.92500            1          3
# 3             2        26.55000            1          1
# 4             1         8.05000            0          3
#
# [5 rows x 22 columns]

# %%
#  Survival as boolean
df['survived_bool'] = df['survived'].astype(bool)

# %%
#  Name length
df['name_length'] = df['who'].apply(lambda x: len(str(x)))

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  ...  alone is_child is_elderly age_group  total_people  \
# 0    man  ...  False    False      False     Adult             2
# 1  woman  ...  False    False      False     Adult             2
# 2  woman  ...   True    False      False     Adult             1
# 3  woman  ...  False    False      False     Adult             2
# 4    man  ...   True    False      False     Adult             1
#
#    fare_per_person  sex_encoded class_num  survived_bool  name_length
# 0          3.62500            0         3          False            3
# 1         35.64165            1         1           True            5
# 2          7.92500            1         3           True            5
# 3         26.55000            1         1           True            5
# 4          8.05000            0         3          False            3
#
# [5 rows x 24 columns]

# %%
#  Title from name
df['title'] = df['who']

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  ...  is_child is_elderly age_group total_people  fare_per_person  \
# 0    man  ...     False      False     Adult            2          3.62500
# 1  woman  ...     False      False     Adult            2         35.64165
# 2  woman  ...     False      False     Adult            1          7.92500
# 3  woman  ...     False      False     Adult            2         26.55000
# 4    man  ...     False      False     Adult            1          8.05000
#
#    sex_encoded  class_num survived_bool  name_length  title
# 0            0          3         False            3    man
# 1            1          1          True            5  woman
# 2            1          3          True            5  woman
# 3            1          1          True            5  woman
# 4            0          3         False            3    man
#
# [5 rows x 25 columns]

# %%
#  Log fare
df['log_fare'] = np.log1p(df['fare'])

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  ...  is_elderly age_group total_people fare_per_person  sex_encoded  \
# 0    man  ...       False     Adult            2         3.62500            0
# 1  woman  ...       False     Adult            2        35.64165            1
# 2  woman  ...       False     Adult            1         7.92500            1
# 3  woman  ...       False     Adult            2        26.55000            1
# 4    man  ...       False     Adult            1         8.05000            0
#
#    class_num  survived_bool name_length  title  log_fare
# 0          3          False           3    man  2.110213
# 1          1           True           5  woman  4.280593
# 2          3           True           5  woman  2.188856
# 3          1           True           5  woman  3.990834
# 4          3          False           3    man  2.202765
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Boolean Masks & Filters

# %%
#  Males under 30
df[(df['sex'] == 'male') & (df['age'] < 30)]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 5           0       3  male  28.0      0      0   8.4583        Q   Third
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# 12          0       3  male  20.0      0      0   8.0500        S   Third
# 16          0       3  male   2.0      4      1  29.1250        Q   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 878         0       3  male  28.0      0      0   7.8958        S   Third
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 0      man  ...       False     Adult            2        3.625000
# 5      man  ...       False     Adult            1        8.458300
# 7    child  ...       False     Child            5        4.215000
# 12     man  ...       False     Adult            1        8.050000
# 16   child  ...       False     Child            6        4.854167
# ..     ...  ...         ...       ...          ...             ...
# 878    man  ...       False     Adult            1        7.895800
# 883    man  ...       False     Adult            1       10.500000
# 884    man  ...       False     Adult            1        7.050000
# 886    man  ...       False     Adult            1       13.000000
# 889    man  ...       False     Adult            1       30.000000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 0              0          3          False           3    man  2.110213
# 5              0          3          False           3    man  2.246893
# 7              0          3          False           5  child  3.094446
# 12             0          3          False           3    man  2.202765
# 16             0          3          False           5  child  3.405355
# ..           ...        ...            ...         ...    ...       ...
# 878            0          3          False           3    man  2.185579
# 883            0          2          False           3    man  2.442347
# 884            0          3          False           3    man  2.085672
# 886            0          2          False           3    man  2.639057
# 889            0          1           True           3    man  3.433987
#
# [361 rows x 26 columns]

# %%
# Females over 50
df[(df['sex'] == 'female') & (df['age'] > 50)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 15          1       2  female  55.0      0      0   16.0000        S  Second
# 195         1       1  female  58.0      0      0  146.5208        C   First
# 268         1       1  female  58.0      0      1  153.4625        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 366         1       1  female  60.0      1      0   75.2500        C   First
# 483         1       3  female  63.0      0      0    9.5875        S   Third
# 496         1       1  female  54.0      1      0   78.2667        C   First
# 513         1       1  female  54.0      1      0   59.4000        C   First
# 571         1       1  female  53.0      2      0   51.4792        S   First
# 591         1       1  female  52.0      1      0   78.2667        C   First
# 765         1       1  female  51.0      1      0   77.9583        S   First
# 772         0       2  female  57.0      0      0   10.5000        S  Second
# 774         1       2  female  54.0      1      3   23.0000        S  Second
# 820         1       1  female  52.0      1      1   93.5000        S   First
# 829         1       1  female  62.0      0      0   80.0000        S   First
# 879         1       1  female  56.0      0      1   83.1583        C   First
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 11   woman  ...       False     Adult            1       26.550000
# 15   woman  ...       False     Adult            1       16.000000
# 195  woman  ...       False     Adult            1      146.520800
# 268  woman  ...       False     Adult            2       76.731250
# 275  woman  ...        True    Senior            2       38.979150
# 366  woman  ...       False     Adult            2       37.625000
# 483  woman  ...        True    Senior            1        9.587500
# 496  woman  ...       False     Adult            2       39.133350
# 513  woman  ...       False     Adult            2       29.700000
# 571  woman  ...       False     Adult            3       17.159733
# 591  woman  ...       False     Adult            2       39.133350
# 765  woman  ...       False     Adult            2       38.979150
# 772  woman  ...       False     Adult            1       10.500000
# 774  woman  ...       False     Adult            5        4.600000
# 820  woman  ...       False     Adult            3       31.166667
# 829  woman  ...        True    Senior            1       80.000000
# 879  woman  ...       False     Adult            2       41.579150
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 11             1          1           True           5  woman  3.316003
# 15             1          2           True           5  woman  2.833213
# 195            1          1           True           5  woman  4.993969
# 268            1          1           True           5  woman  5.039951
# 275            1          1           True           5  woman  4.368920
# 366            1          1           True           5  woman  4.334017
# 483            1          3           True           5  woman  2.359674
# 496            1          1           True           5  woman  4.372818
# 513            1          1           True           5  woman  4.100989
# 571            1          1           True           5  woman  3.960417
# 591            1          1           True           5  woman  4.372818
# 765            1          1           True           5  woman  4.368920
# 772            1          2          False           5  woman  2.442347
# 774            1          2           True           5  woman  3.178054
# 820            1          1           True           5  woman  4.548600
# 829            1          1           True           5  woman  4.394449
# 879            1          1           True           5  woman  4.432700
#
# [17 rows x 26 columns]

# %%
#  First class children
df[(df['class'] == 'First') & (df['age'] < 12)]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 305         1       1    male   0.92      1      2  151.5500        S  First
# 445         1       1    male   4.00      0      2   81.8583        S  First
# 802         1       1    male  11.00      1      2  120.0000        S  First
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 297  child  ...       False     Child            4         37.8875
# 305  child  ...       False     Child            4         37.8875
# 445  child  ...       False     Child            3         27.2861
# 802  child  ...       False     Child            4         30.0000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 297            1          1          False           5  child  5.027492
# 305            0          1           True           5  child  5.027492
# 445            0          1           True           5  child  4.417132
# 802            0          1           True           5  child  4.795791
#
# [4 rows x 26 columns]

# %%
#  Survived elderly
df[(df['age'] > 60) & (df['survived'] == 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 275         1       1  female  63.0      1      0  77.9583        S   First
# 483         1       3  female  63.0      0      0   9.5875        S   Third
# 570         1       2    male  62.0      0      0  10.5000        S  Second
# 630         1       1    male  80.0      0      0  30.0000        S   First
# 829         1       1  female  62.0      0      0  80.0000        S   First
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 275  woman  ...        True    Senior            2        38.97915
# 483  woman  ...        True    Senior            1         9.58750
# 570    man  ...        True    Senior            1        10.50000
# 630    man  ...        True    Senior            1        30.00000
# 829  woman  ...        True    Senior            1        80.00000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 275            1          1           True           5  woman  4.368920
# 483            1          3           True           5  woman  2.359674
# 570            0          2           True           3    man  2.442347
# 630            0          1           True           3    man  3.433987
# 829            1          1           True           5  woman  4.394449
#
# [5 rows x 26 columns]

# %%
#  Rich (fare > 100)
df[df['fare'] > 100]
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked  class  \
# 27          0       1    male  19.00      3      2  263.0000        S  First
# 31          1       1  female  28.00      1      0  146.5208        C  First
# 88          1       1  female  23.00      3      2  263.0000        S  First
# 118         0       1    male  24.00      0      1  247.5208        C  First
# 195         1       1  female  58.00      0      0  146.5208        C  First
# 215         1       1  female  31.00      1      0  113.2750        C  First
# 258         1       1  female  35.00      0      0  512.3292        C  First
# 268         1       1  female  58.00      0      1  153.4625        S  First
# 269         1       1  female  35.00      0      0  135.6333        S  First
# 297         0       1  female   2.00      1      2  151.5500        S  First
# 299         1       1  female  50.00      0      1  247.5208        C  First
# 305         1       1    male   0.92      1      2  151.5500        S  First
# 306         1       1  female  28.00      0      0  110.8833        C  First
# 307         1       1  female  17.00      1      0  108.9000        C  First
# 311         1       1  female  18.00      2      2  262.3750        C  First
# 318         1       1  female  31.00      0      2  164.8667        S  First
# 319         1       1  female  40.00      1      1  134.5000        C  First
# 325         1       1  female  36.00      0      0  135.6333        C  First
# 332         0       1    male  38.00      0      1  153.4625        S  First
# 334         1       1  female  28.00      1      0  133.6500        S  First
# 337         1       1  female  41.00      0      0  134.5000        C  First
# 341         1       1  female  24.00      3      2  263.0000        S  First
# 373         0       1    male  22.00      0      0  135.6333        C  First
# 377         0       1    male  27.00      0      2  211.5000        C  First
# 380         1       1  female  42.00      0      0  227.5250        C  First
# 390         1       1    male  36.00      1      2  120.0000        S  First
# 393         1       1  female  23.00      1      0  113.2750        C  First
# 435         1       1  female  14.00      1      2  120.0000        S  First
# 438         0       1    male  64.00      1      4  263.0000        S  First
# 498         0       1  female  25.00      1      2  151.5500        S  First
# 505         0       1    male  18.00      1      0  108.9000        C  First
# 527         0       1    male  28.00      0      0  221.7792        S  First
# 537         1       1  female  30.00      0      0  106.4250        C  First
# 544         0       1    male  50.00      1      0  106.4250        C  First
# 550         1       1    male  17.00      0      2  110.8833        C  First
# 557         0       1    male  28.00      0      0  227.5250        C  First
# 581         1       1  female  39.00      1      1  110.8833        C  First
# 609         1       1  female  40.00      0      0  153.4625        S  First
# 659         0       1    male  58.00      0      2  113.2750        C  First
# 660         1       1    male  50.00      2      0  133.6500        S  First
# 679         1       1    male  36.00      0      1  512.3292        C  First
# 689         1       1  female  15.00      0      1  211.3375        S  First
# 698         0       1    male  49.00      1      1  110.8833        C  First
# 700         1       1  female  18.00      1      0  227.5250        C  First
# 708         1       1  female  22.00      0      0  151.5500        S  First
# 716         1       1  female  38.00      0      0  227.5250        C  First
# 730         1       1  female  29.00      0      0  211.3375        S  First
# 737         1       1    male  35.00      0      0  512.3292        C  First
# 742         1       1  female  21.00      2      2  262.3750        C  First
# 763         1       1  female  36.00      1      2  120.0000        S  First
# 779         1       1  female  43.00      0      1  211.3375        S  First
# 802         1       1    male  11.00      1      2  120.0000        S  First
# 856         1       1  female  45.00      1      1  164.8667        S  First
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 27     man  ...       False     Adult            6       43.833333
# 31   woman  ...       False     Adult            2       73.260400
# 88   woman  ...       False     Adult            6       43.833333
# 118    man  ...       False     Adult            2      123.760400
# 195  woman  ...       False     Adult            1      146.520800
# 215  woman  ...       False     Adult            2       56.637500
# 258  woman  ...       False     Adult            1      512.329200
# 268  woman  ...       False     Adult            2       76.731250
# 269  woman  ...       False     Adult            1      135.633300
# 297  child  ...       False     Child            4       37.887500
# 299  woman  ...       False     Adult            2      123.760400
# 305  child  ...       False     Child            4       37.887500
# 306  woman  ...       False     Adult            1      110.883300
# 307  woman  ...       False      Teen            2       54.450000
# 311  woman  ...       False      Teen            5       52.475000
# 318  woman  ...       False     Adult            3       54.955567
# 319  woman  ...       False     Adult            3       44.833333
# 325  woman  ...       False     Adult            1      135.633300
# 332    man  ...       False     Adult            2       76.731250
# 334  woman  ...       False     Adult            2       66.825000
# 337  woman  ...       False     Adult            1      134.500000
# 341  woman  ...       False     Adult            6       43.833333
# 373    man  ...       False     Adult            1      135.633300
# 377    man  ...       False     Adult            3       70.500000
# 380  woman  ...       False     Adult            1      227.525000
# 390    man  ...       False     Adult            4       30.000000
# 393  woman  ...       False     Adult            2       56.637500
# 435  child  ...       False      Teen            4       30.000000
# 438    man  ...        True    Senior            6       43.833333
# 498  woman  ...       False     Adult            4       37.887500
# 505    man  ...       False      Teen            2       54.450000
# 527    man  ...       False     Adult            1      221.779200
# 537  woman  ...       False     Adult            1      106.425000
# 544    man  ...       False     Adult            2       53.212500
# 550    man  ...       False      Teen            3       36.961100
# 557    man  ...       False     Adult            1      227.525000
# 581  woman  ...       False     Adult            3       36.961100
# 609  woman  ...       False     Adult            1      153.462500
# 659    man  ...       False     Adult            3       37.758333
# 660    man  ...       False     Adult            3       44.550000
# 679    man  ...       False     Adult            2      256.164600
# 689  child  ...       False      Teen            2      105.668750
# 698    man  ...       False     Adult            3       36.961100
# 700  woman  ...       False      Teen            2      113.762500
# 708  woman  ...       False     Adult            1      151.550000
# 716  woman  ...       False     Adult            1      227.525000
# 730  woman  ...       False     Adult            1      211.337500
# 737    man  ...       False     Adult            1      512.329200
# 742  woman  ...       False     Adult            5       52.475000
# 763  woman  ...       False     Adult            4       30.000000
# 779  woman  ...       False     Adult            2      105.668750
# 802  child  ...       False     Child            4       30.000000
# 856  woman  ...       False     Adult            3       54.955567
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 27             0          1          False           3    man  5.575949
# 31             1          1           True           5  woman  4.993969
# 88             1          1           True           5  woman  5.575949
# 118            0          1          False           3    man  5.515527
# 195            1          1           True           5  woman  4.993969
# 215            1          1           True           5  woman  4.738608
# 258            1          1           True           5  woman  6.240917
# 268            1          1           True           5  woman  5.039951
# 269            1          1           True           5  woman  4.917301
# 297            1          1          False           5  child  5.027492
# 299            1          1           True           5  woman  5.515527
# 305            0          1           True           5  child  5.027492
# 306            1          1           True           5  woman  4.717456
# 307            1          1           True           5  woman  4.699571
# 311            1          1           True           5  woman  5.573579
# 318            1          1           True           5  woman  5.111184
# 319            1          1           True           5  woman  4.908972
# 325            1          1           True           5  woman  4.917301
# 332            0          1          False           3    man  5.039951
# 334            1          1           True           5  woman  4.902679
# 337            1          1           True           5  woman  4.908972
# 341            1          1           True           5  woman  5.575949
# 373            0          1          False           3    man  4.917301
# 377            0          1          False           3    man  5.358942
# 380            1          1           True           5  woman  5.431646
# 390            0          1           True           3    man  4.795791
# 393            1          1           True           5  woman  4.738608
# 435            1          1           True           5  child  4.795791
# 438            0          1          False           3    man  5.575949
# 498            1          1          False           5  woman  5.027492
# 505            0          1          False           3    man  4.699571
# 527            0          1          False           3    man  5.406181
# 537            1          1           True           5  woman  4.676793
# 544            0          1          False           3    man  4.676793
# 550            0          1           True           3    man  4.717456
# 557            0          1          False           3    man  5.431646
# 581            1          1           True           5  woman  4.717456
# 609            1          1           True           5  woman  5.039951
# 659            0          1          False           3    man  4.738608
# 660            0          1           True           3    man  4.902679
# 679            0          1           True           3    man  6.240917
# 689            1          1           True           5  child  5.358177
# 698            0          1          False           3    man  4.717456
# 700            1          1           True           5  woman  5.431646
# 708            1          1           True           5  woman  5.027492
# 716            1          1           True           5  woman  5.431646
# 730            1          1           True           5  woman  5.358177
# 737            0          1           True           3    man  6.240917
# 742            1          1           True           5  woman  5.573579
# 763            1          1           True           5  woman  4.795791
# 779            1          1           True           5  woman  5.358177
# 802            0          1           True           5  child  4.795791
# 856            1          1           True           5  woman  5.111184
#
# [53 rows x 26 columns]

# %%
#  Third class and low fare
df[(df['class'] == 'Third') & (df['fare'] < 10)]
# Out:
#      survived  pclass     sex   age  sibsp  parch    fare embarked  class  \
# 0           0       3    male  22.0      1      0  7.2500        S  Third
# 2           1       3  female  26.0      0      0  7.9250        S  Third
# 4           0       3    male  35.0      0      0  8.0500        S  Third
# 5           0       3    male  28.0      0      0  8.4583        Q  Third
# 12          0       3    male  20.0      0      0  8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...     ...      ...    ...
# 877         0       3    male  19.0      0      0  7.8958        S  Third
# 878         0       3    male  28.0      0      0  7.8958        S  Third
# 881         0       3    male  33.0      0      0  7.8958        S  Third
# 884         0       3    male  25.0      0      0  7.0500        S  Third
# 890         0       3    male  32.0      0      0  7.7500        Q  Third
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 0      man  ...       False     Adult            2          3.6250
# 2    woman  ...       False     Adult            1          7.9250
# 4      man  ...       False     Adult            1          8.0500
# 5      man  ...       False     Adult            1          8.4583
# 12     man  ...       False     Adult            1          8.0500
# ..     ...  ...         ...       ...          ...             ...
# 877    man  ...       False     Adult            1          7.8958
# 878    man  ...       False     Adult            1          7.8958
# 881    man  ...       False     Adult            1          7.8958
# 884    man  ...       False     Adult            1          7.0500
# 890    man  ...       False     Adult            1          7.7500
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 0              0          3          False           3    man  2.110213
# 2              1          3           True           5  woman  2.188856
# 4              0          3          False           3    man  2.202765
# 5              0          3          False           3    man  2.246893
# 12             0          3          False           3    man  2.202765
# ..           ...        ...            ...         ...    ...       ...
# 877            0          3          False           3    man  2.185579
# 878            0          3          False           3    man  2.185579
# 881            0          3          False           3    man  2.185579
# 884            0          3          False           3    man  2.085672
# 890            0          3          False           3    man  2.169054
#
# [324 rows x 26 columns]

# %%
#  Embarked at Cherbourg
df[df['embarked'] == 'C']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 19          1       3  female  28.0      0      0   7.2250        C   Third
# 26          0       3    male  28.0      0      0   7.2250        C   Third
# 30          0       1    male  40.0      0      0  27.7208        C   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 866         1       2  female  27.0      1      0  13.8583        C  Second
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 1    woman  ...       False     Adult            2        35.64165
# 9    child  ...       False      Teen            2        15.03540
# 19   woman  ...       False     Adult            1         7.22500
# 26     man  ...       False     Adult            1         7.22500
# 30     man  ...       False     Adult            1        27.72080
# ..     ...  ...         ...       ...          ...             ...
# 866  woman  ...       False     Adult            2         6.92915
# 874  woman  ...       False     Adult            2        12.00000
# 875  child  ...       False      Teen            1         7.22500
# 879  woman  ...       False     Adult            2        41.57915
# 889    man  ...       False     Adult            1        30.00000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 1              1          1           True           5  woman  4.280593
# 9              1          2           True           5  child  3.436268
# 19             1          3           True           5  woman  2.107178
# 26             0          3          False           3    man  2.107178
# 30             0          1          False           3    man  3.357622
# ..           ...        ...            ...         ...    ...       ...
# 866            1          2           True           5  woman  2.698559
# 874            1          2           True           5  woman  3.218876
# 875            1          3           True           5  child  2.107178
# 879            1          1           True           5  woman  4.432700
# 889            0          1           True           3    man  3.433987
#
# [168 rows x 26 columns]

# %%
#  Not embarked at Southampton
df[df['embarked'] != 'S']
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 5           0       3    male  28.0      0      0   8.4583        Q   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# 19          1       3  female  28.0      0      0   7.2250        C   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 1    woman  ...       False     Adult            2       35.641650
# 5      man  ...       False     Adult            1        8.458300
# 9    child  ...       False      Teen            2       15.035400
# 16   child  ...       False     Child            6        4.854167
# 19   woman  ...       False     Adult            1        7.225000
# ..     ...  ...         ...       ...          ...             ...
# 875  child  ...       False      Teen            1        7.225000
# 879  woman  ...       False     Adult            2       41.579150
# 885  woman  ...       False     Adult            6        4.854167
# 889    man  ...       False     Adult            1       30.000000
# 890    man  ...       False     Adult            1        7.750000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 1              1          1           True           5  woman  4.280593
# 5              0          3          False           3    man  2.246893
# 9              1          2           True           5  child  3.436268
# 16             0          3          False           5  child  3.405355
# 19             1          3           True           5  woman  2.107178
# ..           ...        ...            ...         ...    ...       ...
# 875            1          3           True           5  child  2.107178
# 879            1          1           True           5  woman  4.432700
# 885            1          3          False           5  woman  3.405355
# 889            0          1           True           3    man  3.433987
# 890            0          3          False           3    man  2.169054
#
# [245 rows x 26 columns]

# %%
#  Children who died
df[(df['age'] < 12) & (df['survived'] == 0)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 7           0       3    male   2.0      3      1   21.0750        S  Third
# 16          0       3    male   2.0      4      1   29.1250        Q  Third
# 24          0       3  female   8.0      3      1   21.0750        S  Third
# 50          0       3    male   7.0      4      1   39.6875        S  Third
# 59          0       3    male  11.0      5      2   46.9000        S  Third
# 63          0       3    male   4.0      3      2   27.9000        S  Third
# 119         0       3  female   2.0      4      2   31.2750        S  Third
# 147         0       3  female   9.0      2      2   34.3750        S  Third
# 164         0       3    male   1.0      4      1   39.6875        S  Third
# 171         0       3    male   4.0      4      1   29.1250        Q  Third
# 182         0       3    male   9.0      4      2   31.3875        S  Third
# 205         0       3  female   2.0      0      1   10.4625        S  Third
# 278         0       3    male   7.0      4      1   29.1250        Q  Third
# 297         0       1  female   2.0      1      2  151.5500        S  First
# 374         0       3  female   3.0      3      1   21.0750        S  Third
# 386         0       3    male   1.0      5      2   46.9000        S  Third
# 419         0       3  female  10.0      0      2   24.1500        S  Third
# 480         0       3    male   9.0      5      2   46.9000        S  Third
# 541         0       3  female   9.0      4      2   31.2750        S  Third
# 542         0       3  female  11.0      4      2   31.2750        S  Third
# 634         0       3  female   9.0      3      2   27.9000        S  Third
# 642         0       3  female   2.0      3      2   27.9000        S  Third
# 731         0       3    male  11.0      0      0   18.7875        C  Third
# 787         0       3    male   8.0      4      1   29.1250        Q  Third
# 813         0       3  female   6.0      4      2   31.2750        S  Third
# 819         0       3    male  10.0      3      2   27.9000        S  Third
# 824         0       3    male   2.0      4      1   39.6875        S  Third
# 850         0       3    male   4.0      4      2   31.2750        S  Third
# 852         0       3  female   9.0      1      1   15.2458        C  Third
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 7    child  ...       False     Child            5        4.215000
# 16   child  ...       False     Child            6        4.854167
# 24   child  ...       False     Child            5        4.215000
# 50   child  ...       False     Child            6        6.614583
# 59   child  ...       False     Child            8        5.862500
# 63   child  ...       False     Child            6        4.650000
# 119  child  ...       False     Child            7        4.467857
# 147  child  ...       False     Child            5        6.875000
# 164  child  ...       False     Child            6        6.614583
# 171  child  ...       False     Child            6        4.854167
# 182  child  ...       False     Child            7        4.483929
# 205  child  ...       False     Child            2        5.231250
# 278  child  ...       False     Child            6        4.854167
# 297  child  ...       False     Child            4       37.887500
# 374  child  ...       False     Child            5        4.215000
# 386  child  ...       False     Child            8        5.862500
# 419  child  ...       False     Child            3        8.050000
# 480  child  ...       False     Child            8        5.862500
# 541  child  ...       False     Child            7        4.467857
# 542  child  ...       False     Child            7        4.467857
# 634  child  ...       False     Child            6        4.650000
# 642  child  ...       False     Child            6        4.650000
# 731  child  ...       False     Child            1       18.787500
# 787  child  ...       False     Child            6        4.854167
# 813  child  ...       False     Child            7        4.467857
# 819  child  ...       False     Child            6        4.650000
# 824  child  ...       False     Child            6        6.614583
# 850  child  ...       False     Child            7        4.467857
# 852  child  ...       False     Child            3        5.081933
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 7              0          3          False           5  child  3.094446
# 16             0          3          False           5  child  3.405355
# 24             1          3          False           5  child  3.094446
# 50             0          3          False           5  child  3.705921
# 59             0          3          False           5  child  3.869116
# 63             0          3          False           5  child  3.363842
# 119            1          3          False           5  child  3.474293
# 147            1          3          False           5  child  3.566005
# 164            0          3          False           5  child  3.705921
# 171            0          3          False           5  child  3.405355
# 182            0          3          False           5  child  3.477773
# 205            1          3          False           5  child  2.439081
# 278            0          3          False           5  child  3.405355
# 297            1          1          False           5  child  5.027492
# 374            1          3          False           5  child  3.094446
# 386            0          3          False           5  child  3.869116
# 419            1          3          False           5  child  3.224858
# 480            0          3          False           5  child  3.869116
# 541            1          3          False           5  child  3.474293
# 542            1          3          False           5  child  3.474293
# 634            1          3          False           5  child  3.363842
# 642            1          3          False           5  child  3.363842
# 731            0          3          False           5  child  2.985050
# 787            0          3          False           5  child  3.405355
# 813            1          3          False           5  child  3.474293
# 819            0          3          False           5  child  3.363842
# 824            0          3          False           5  child  3.705921
# 850            0          3          False           5  child  3.474293
# 852            1          3          False           5  child  2.787834
#
# [29 rows x 26 columns]

# %%
#  Elders who survived
df[(df['age'] > 60) & (df['survived'] == 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 275         1       1  female  63.0      1      0  77.9583        S   First
# 483         1       3  female  63.0      0      0   9.5875        S   Third
# 570         1       2    male  62.0      0      0  10.5000        S  Second
# 630         1       1    male  80.0      0      0  30.0000        S   First
# 829         1       1  female  62.0      0      0  80.0000        S   First
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 275  woman  ...        True    Senior            2        38.97915
# 483  woman  ...        True    Senior            1         9.58750
# 570    man  ...        True    Senior            1        10.50000
# 630    man  ...        True    Senior            1        30.00000
# 829  woman  ...        True    Senior            1        80.00000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 275            1          1           True           5  woman  4.368920
# 483            1          3           True           5  woman  2.359674
# 570            0          2           True           3    man  2.442347
# 630            0          1           True           3    man  3.433987
# 829            1          1           True           5  woman  4.394449
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Value Counts & Crosstabs

# %%
#  Count of passengers by sex
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
#  Count of survival by class
pd.crosstab(df['class'], df['survived'])
# Out:
# survived    0    1
# class
# First      80  136
# Second     97   87
# Third     372  119

# %%
#  Survival by sex
pd.crosstab(df['sex'], df['survived'])
# Out:
# survived    0    1
# sex
# female     81  233
# male      468  109

# %%
#  Sex & class crosstab
pd.crosstab(df['sex'], df['class'])
# Out:
# class   First  Second  Third
# sex
# female     94      76    144
# male      122     108    347

# %%
#  Survived by embark_town
pd.crosstab(df['embark_town'], df['survived'])
# Out:
# survived       0    1
# embark_town
# Cherbourg     75   93
# Queenstown    47   30
# Southampton  427  217
# Unknown        0    2

# %%
#  Normalize crosstab
pd.crosstab(df['sex'], df['survived'], normalize='index')
# Out:
# survived         0         1
# sex
# female    0.257962  0.742038
# male      0.811092  0.188908

# %%
#  Percent survived by class
df.groupby('class')['survived'].mean() * 100
# Out:
# class
# First     62.962963
# Second    47.282609
# Third     24.236253
# Name: survived, dtype: float64

# %%
#  Who category counts
df['who'].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
#  Survival by age group
pd.crosstab(df['age_group'], df['survived'])
# Out:
# survived     0    1
# age_group
# Child       29   40
# Teen        40   30
# Adult      463  267
# Senior      17    5

# %%
#  Count unique ages
df['age'].nunique()
# Out:
# 88

# %% [markdown]
# #### Advanced Filtering & Sampling

# %%
# 80. Count unique ages
df['age'].nunique()
# Out:
# 88

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 0      man  ...       False     Adult            2         3.62500
# 1    woman  ...       False     Adult            2        35.64165
# 2    woman  ...       False     Adult            1         7.92500
# 3    woman  ...       False     Adult            2        26.55000
# 4      man  ...       False     Adult            1         8.05000
# ..     ...  ...         ...       ...          ...             ...
# 886    man  ...       False     Adult            1        13.00000
# 887  woman  ...       False     Adult            1        30.00000
# 888  woman  ...       False     Adult            4         5.86250
# 889    man  ...       False     Adult            1        30.00000
# 890    man  ...       False     Adult            1         7.75000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 0              0          3          False           3    man  2.110213
# 1              1          1           True           5  woman  4.280593
# 2              1          3           True           5  woman  2.188856
# 3              1          1           True           5  woman  3.990834
# 4              0          3          False           3    man  2.202765
# ..           ...        ...            ...         ...    ...       ...
# 886            0          2          False           3    man  2.639057
# 887            1          1           True           5  woman  3.433987
# 888            1          3          False           5  woman  3.196630
# 889            0          1           True           3    man  3.433987
# 890            0          3          False           3    man  2.169054
#
# [891 rows x 26 columns]

# %%
#  Drop duplicate sex entries (demonstration)
df.drop_duplicates(subset='sex')
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  ...  is_elderly age_group total_people fare_per_person  sex_encoded  \
# 0    man  ...       False     Adult            2         3.62500            0
# 1  woman  ...       False     Adult            2        35.64165            1
#
#    class_num  survived_bool name_length  title  log_fare
# 0          3          False           3    man  2.110213
# 1          1           True           5  woman  4.280593
#
# [2 rows x 26 columns]

# %%
# Sample 10 random rows
df.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 95          0       3    male  28.0      0      0    8.0500        S   Third
# 544         0       1    male  50.0      1      0  106.4250        C   First
# 821         1       3    male  27.0      0      0    8.6625        S   Third
# 115         0       3    male  21.0      0      0    7.9250        S   Third
# 699         0       3    male  42.0      0      0    7.6500        S   Third
# 406         0       3    male  51.0      0      0    7.7500        S   Third
# 120         0       2    male  21.0      2      0   73.5000        S  Second
# 60          0       3    male  22.0      0      0    7.2292        C   Third
# 657         0       3  female  32.0      1      1   15.5000        Q   Third
# 682         0       3    male  20.0      0      0    9.2250        S   Third
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 95     man  ...       False     Adult            1        8.050000
# 544    man  ...       False     Adult            2       53.212500
# 821    man  ...       False     Adult            1        8.662500
# 115    man  ...       False     Adult            1        7.925000
# 699    man  ...       False     Adult            1        7.650000
# 406    man  ...       False     Adult            1        7.750000
# 120    man  ...       False     Adult            3       24.500000
# 60     man  ...       False     Adult            1        7.229200
# 657  woman  ...       False     Adult            3        5.166667
# 682    man  ...       False     Adult            1        9.225000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 95             0          3          False           3    man  2.202765
# 544            0          1          False           3    man  4.676793
# 821            0          3           True           3    man  2.268252
# 115            0          3          False           3    man  2.188856
# 699            0          3          False           3    man  2.157559
# 406            0          3          False           3    man  2.169054
# 120            0          2          False           3    man  4.310799
# 60             0          3          False           3    man  2.107689
# 657            1          3          False           5  woman  2.803360
# 682            0          3          False           3    man  2.324836
#
# [10 rows x 26 columns]

# %%
#  Sample 5% of data
df.sample(frac=0.05)
# Out:
#      survived  pclass     sex    age  sibsp  parch      fare embarked   class  \
# 316         1       2  female  24.00      1      0   26.0000        S  Second
# 845         0       3    male  42.00      0      0    7.5500        S   Third
# 552         0       3    male  28.00      0      0    7.8292        Q   Third
# 401         0       3    male  26.00      0      0    8.0500        S   Third
# 275         1       1  female  63.00      1      0   77.9583        S   First
# 319         1       1  female  40.00      1      1  134.5000        C   First
# 659         0       1    male  58.00      0      2  113.2750        C   First
# 192         1       3  female  19.00      1      0    7.8542        S   Third
# 42          0       3    male  28.00      0      0    7.8958        C   Third
# 451         0       3    male  28.00      1      0   19.9667        S   Third
# 505         0       1    male  18.00      1      0  108.9000        C   First
# 446         1       2  female  13.00      0      1   19.5000        S  Second
# 426         1       2  female  28.00      1      0   26.0000        S  Second
# 27          0       1    male  19.00      3      2  263.0000        S   First
# 242         0       2    male  29.00      0      0   10.5000        S  Second
# 70          0       2    male  32.00      0      0   10.5000        S  Second
# 688         0       3    male  18.00      0      0    7.7958        S   Third
# 235         0       3  female  28.00      0      0    7.5500        S   Third
# 630         1       1    male  80.00      0      0   30.0000        S   First
# 4           0       3    male  35.00      0      0    8.0500        S   Third
# 305         1       1    male   0.92      1      2  151.5500        S   First
# 633         0       1    male  28.00      0      0    0.0000        S   First
# 456         0       1    male  65.00      0      0   26.5500        S   First
# 77          0       3    male  28.00      0      0    8.0500        S   Third
# 788         1       3    male   1.00      1      2   20.5750        S   Third
# 757         0       2    male  18.00      0      0   11.5000        S  Second
# 585         1       1  female  18.00      0      2   79.6500        S   First
# 569         1       3    male  32.00      0      0    7.8542        S   Third
# 0           0       3    male  22.00      1      0    7.2500        S   Third
# 579         1       3    male  32.00      0      0    7.9250        S   Third
# 329         1       1  female  16.00      0      1   57.9792        C   First
# 127         1       3    male  24.00      0      0    7.1417        S   Third
# 654         0       3  female  18.00      0      0    6.7500        Q   Third
# 765         1       1  female  51.00      1      0   77.9583        S   First
# 143         0       3    male  19.00      0      0    6.7500        Q   Third
# 560         0       3    male  28.00      0      0    7.7500        Q   Third
# 724         1       1    male  27.00      1      0   53.1000        S   First
# 187         1       1    male  45.00      0      0   26.5500        S   First
# 31          1       1  female  28.00      1      0  146.5208        C   First
# 10          1       3  female   4.00      1      1   16.7000        S   Third
# 442         0       3    male  25.00      1      0    7.7750        S   Third
# 717         1       2  female  27.00      0      0   10.5000        S  Second
# 220         1       3    male  16.00      0      0    8.0500        S   Third
# 368         1       3  female  28.00      0      0    7.7500        Q   Third
# 635         1       2  female  28.00      0      0   13.0000        S  Second
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 316  woman  ...       False     Adult            2       13.000000
# 845    man  ...       False     Adult            1        7.550000
# 552    man  ...       False     Adult            1        7.829200
# 401    man  ...       False     Adult            1        8.050000
# 275  woman  ...        True    Senior            2       38.979150
# 319  woman  ...       False     Adult            3       44.833333
# 659    man  ...       False     Adult            3       37.758333
# 192  woman  ...       False     Adult            2        3.927100
# 42     man  ...       False     Adult            1        7.895800
# 451    man  ...       False     Adult            2        9.983350
# 505    man  ...       False      Teen            2       54.450000
# 446  child  ...       False      Teen            2        9.750000
# 426  woman  ...       False     Adult            2       13.000000
# 27     man  ...       False     Adult            6       43.833333
# 242    man  ...       False     Adult            1       10.500000
# 70     man  ...       False     Adult            1       10.500000
# 688    man  ...       False      Teen            1        7.795800
# 235  woman  ...       False     Adult            1        7.550000
# 630    man  ...        True    Senior            1       30.000000
# 4      man  ...       False     Adult            1        8.050000
# 305  child  ...       False     Child            4       37.887500
# 633    man  ...       False     Adult            1        0.000000
# 456    man  ...        True    Senior            1       26.550000
# 77     man  ...       False     Adult            1        8.050000
# 788  child  ...       False     Child            4        5.143750
# 757    man  ...       False      Teen            1       11.500000
# 585  woman  ...       False      Teen            3       26.550000
# 569    man  ...       False     Adult            1        7.854200
# 0      man  ...       False     Adult            2        3.625000
# 579    man  ...       False     Adult            1        7.925000
# 329  woman  ...       False      Teen            2       28.989600
# 127    man  ...       False     Adult            1        7.141700
# 654  woman  ...       False      Teen            1        6.750000
# 765  woman  ...       False     Adult            2       38.979150
# 143    man  ...       False     Adult            1        6.750000
# 560    man  ...       False     Adult            1        7.750000
# 724    man  ...       False     Adult            2       26.550000
# 187    man  ...       False     Adult            1       26.550000
# 31   woman  ...       False     Adult            2       73.260400
# 10   child  ...       False     Child            3        5.566667
# 442    man  ...       False     Adult            2        3.887500
# 717  woman  ...       False     Adult            1       10.500000
# 220    man  ...       False      Teen            1        8.050000
# 368  woman  ...       False     Adult            1        7.750000
# 635  woman  ...       False     Adult            1       13.000000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 316            1          2           True           5  woman  3.295837
# 845            0          3          False           3    man  2.145931
# 552            0          3          False           3    man  2.178064
# 401            0          3          False           3    man  2.202765
# 275            1          1           True           5  woman  4.368920
# 319            1          1           True           5  woman  4.908972
# 659            0          1          False           3    man  4.738608
# 192            1          3           True           5  woman  2.180892
# 42             0          3          False           3    man  2.185579
# 451            0          3          False           3    man  3.042935
# 505            0          1          False           3    man  4.699571
# 446            1          2           True           5  child  3.020425
# 426            1          2           True           5  woman  3.295837
# 27             0          1          False           3    man  5.575949
# 242            0          2          False           3    man  2.442347
# 70             0          2          False           3    man  2.442347
# 688            0          3          False           3    man  2.174274
# 235            1          3          False           5  woman  2.145931
# 630            0          1           True           3    man  3.433987
# 4              0          3          False           3    man  2.202765
# 305            0          1           True           5  child  5.027492
# 633            0          1          False           3    man  0.000000
# 456            0          1          False           3    man  3.316003
# 77             0          3          False           3    man  2.202765
# 788            0          3           True           5  child  3.071535
# 757            0          2          False           3    man  2.525729
# 585            1          1           True           5  woman  4.390119
# 569            0          3           True           3    man  2.180892
# 0              0          3          False           3    man  2.110213
# 579            0          3           True           3    man  2.188856
# 329            1          1           True           5  woman  4.077185
# 127            0          3           True           3    man  2.096999
# 654            1          3          False           5  woman  2.047693
# 765            1          1           True           5  woman  4.368920
# 143            0          3          False           3    man  2.047693
# 560            0          3          False           3    man  2.169054
# 724            0          1           True           3    man  3.990834
# 187            0          1           True           3    man  3.316003
# 31             1          1           True           5  woman  4.993969
# 10             1          3           True           5  child  2.873565
# 442            0          3          False           3    man  2.171907
# 717            1          2           True           5  woman  2.442347
# 220            0          3           True           3    man  2.202765
# 368            1          3           True           5  woman  2.169054
# 635            1          2           True           5  woman  2.639057
#
# [45 rows x 26 columns]

# %%
#  Filter rows where 'who' contains "man"
df[df['who'].str.contains('man', na=False)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 0      man  ...       False     Adult            2         3.62500
# 1    woman  ...       False     Adult            2        35.64165
# 2    woman  ...       False     Adult            1         7.92500
# 3    woman  ...       False     Adult            2        26.55000
# 4      man  ...       False     Adult            1         8.05000
# ..     ...  ...         ...       ...          ...             ...
# 886    man  ...       False     Adult            1        13.00000
# 887  woman  ...       False     Adult            1        30.00000
# 888  woman  ...       False     Adult            4         5.86250
# 889    man  ...       False     Adult            1        30.00000
# 890    man  ...       False     Adult            1         7.75000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 0              0          3          False           3    man  2.110213
# 1              1          1           True           5  woman  4.280593
# 2              1          3           True           5  woman  2.188856
# 3              1          1           True           5  woman  3.990834
# 4              0          3          False           3    man  2.202765
# ..           ...        ...            ...         ...    ...       ...
# 886            0          2          False           3    man  2.639057
# 887            1          1           True           5  woman  3.433987
# 888            1          3          False           5  woman  3.196630
# 889            0          1           True           3    man  3.433987
# 890            0          3          False           3    man  2.169054
#
# [808 rows x 26 columns]

# %%
#  Age between 20 and 40
df[df['age'].between(20, 40)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 888         0       3  female  28.0      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 0      man  ...       False     Adult            2        3.625000
# 1    woman  ...       False     Adult            2       35.641650
# 2    woman  ...       False     Adult            1        7.925000
# 3    woman  ...       False     Adult            2       26.550000
# 4      man  ...       False     Adult            1        8.050000
# ..     ...  ...         ...       ...          ...             ...
# 885  woman  ...       False     Adult            6        4.854167
# 886    man  ...       False     Adult            1       13.000000
# 888  woman  ...       False     Adult            4        5.862500
# 889    man  ...       False     Adult            1       30.000000
# 890    man  ...       False     Adult            1        7.750000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 0              0          3          False           3    man  2.110213
# 1              1          1           True           5  woman  4.280593
# 2              1          3           True           5  woman  2.188856
# 3              1          1           True           5  woman  3.990834
# 4              0          3          False           3    man  2.202765
# ..           ...        ...            ...         ...    ...       ...
# 885            1          3          False           5  woman  3.405355
# 886            0          2          False           3    man  2.639057
# 888            1          3          False           5  woman  3.196630
# 889            0          1           True           3    man  3.433987
# 890            0          3          False           3    man  2.169054
#
# [577 rows x 26 columns]

# %%
#  Top 5 passengers by fare (show sex and fare)
df.nlargest(5, 'fare')[['sex', 'fare']]
# Out:
#         sex      fare
# 258  female  512.3292
# 679    male  512.3292
# 737    male  512.3292
# 27     male  263.0000
# 88   female  263.0000

# %%
#  Top 5 oldest passengers (show sex and age)
df.nlargest(5, 'age')[['sex', 'age']]
# Out:
#       sex   age
# 630  male  80.0
# 851  male  74.0
# 96   male  71.0
# 493  male  71.0
# 116  male  70.5

# %%
#  Select survivors with family onboard
df[(df['survived'] == 1) & (df['sibsp'] + df['parch'] > 0)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 871         1       1  female  47.0      1      1  52.5542        S   First
# 874         1       2  female  28.0      1      0  24.0000        C  Second
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 1    woman  ...       False     Adult            2       35.641650
# 3    woman  ...       False     Adult            2       26.550000
# 8    woman  ...       False     Adult            3        3.711100
# 9    child  ...       False      Teen            2       15.035400
# 10   child  ...       False     Child            3        5.566667
# ..     ...  ...         ...       ...          ...             ...
# 869  child  ...       False     Child            3        3.711100
# 871  woman  ...       False     Adult            3       17.518067
# 874  woman  ...       False     Adult            2       12.000000
# 879  woman  ...       False     Adult            2       41.579150
# 880  woman  ...       False     Adult            2       13.000000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 1              1          1           True           5  woman  4.280593
# 3              1          1           True           5  woman  3.990834
# 8              1          3           True           5  woman  2.495954
# 9              1          2           True           5  child  3.436268
# 10             1          3           True           5  child  2.873565
# ..           ...        ...            ...         ...    ...       ...
# 869            0          3           True           5  child  2.495954
# 871            1          1           True           5  woman  3.980694
# 874            1          2           True           5  woman  3.218876
# 879            1          1           True           5  woman  4.432700
# 880            1          2           True           5  woman  3.295837
#
# [179 rows x 26 columns]

# %%
# Survivors in first class
df[(df['class'] == 'First') & (df['survived'] == 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 1           1       1  female  38.0      1      0   71.2833        C  First
# 3           1       1  female  35.0      1      0   53.1000        S  First
# 11          1       1  female  58.0      0      0   26.5500        S  First
# 23          1       1    male  28.0      0      0   35.5000        S  First
# 31          1       1  female  28.0      1      0  146.5208        C  First
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 862         1       1  female  48.0      0      0   25.9292        S  First
# 871         1       1  female  47.0      1      1   52.5542        S  First
# 879         1       1  female  56.0      0      1   83.1583        C  First
# 887         1       1  female  19.0      0      0   30.0000        S  First
# 889         1       1    male  26.0      0      0   30.0000        C  First
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 1    woman  ...       False     Adult            2       35.641650
# 3    woman  ...       False     Adult            2       26.550000
# 11   woman  ...       False     Adult            1       26.550000
# 23     man  ...       False     Adult            1       35.500000
# 31   woman  ...       False     Adult            2       73.260400
# ..     ...  ...         ...       ...          ...             ...
# 862  woman  ...       False     Adult            1       25.929200
# 871  woman  ...       False     Adult            3       17.518067
# 879  woman  ...       False     Adult            2       41.579150
# 887  woman  ...       False     Adult            1       30.000000
# 889    man  ...       False     Adult            1       30.000000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 1              1          1           True           5  woman  4.280593
# 3              1          1           True           5  woman  3.990834
# 11             1          1           True           5  woman  3.316003
# 23             0          1           True           3    man  3.597312
# 31             1          1           True           5  woman  4.993969
# ..           ...        ...            ...         ...    ...       ...
# 862            1          1           True           5  woman  3.293211
# 871            1          1           True           5  woman  3.980694
# 879            1          1           True           5  woman  4.432700
# 887            1          1           True           5  woman  3.433987
# 889            0          1           True           3    man  3.433987
#
# [136 rows x 26 columns]

# %%
#  Multiple conditions: male, 2nd class, survived
df[(df['sex'] == 'male') & (df['class'] == 'Second') & (df['survived'] == 1)]
# Out:
#      survived  pclass   sex    age  sibsp  parch     fare embarked   class  \
# 17          1       2  male  28.00      0      0  13.0000        S  Second
# 21          1       2  male  34.00      0      0  13.0000        S  Second
# 78          1       2  male   0.83      0      2  29.0000        S  Second
# 183         1       2  male   1.00      2      1  39.0000        S  Second
# 193         1       2  male   3.00      1      1  26.0000        S  Second
# 226         1       2  male  19.00      0      0  10.5000        S  Second
# 288         1       2  male  42.00      0      0  13.0000        S  Second
# 340         1       2  male   2.00      1      1  26.0000        S  Second
# 407         1       2  male   3.00      1      1  18.7500        S  Second
# 543         1       2  male  32.00      1      0  26.0000        S  Second
# 547         1       2  male  28.00      0      0  13.8625        C  Second
# 549         1       2  male   8.00      1      1  36.7500        S  Second
# 570         1       2  male  62.00      0      0  10.5000        S  Second
# 673         1       2  male  31.00      0      0  13.0000        S  Second
# 755         1       2  male   0.67      1      1  14.5000        S  Second
# 827         1       2  male   1.00      0      2  37.0042        C  Second
# 831         1       2  male   0.83      1      1  18.7500        S  Second
#
#        who  ...  is_elderly age_group total_people fare_per_person  \
# 17     man  ...       False     Adult            1       13.000000
# 21     man  ...       False     Adult            1       13.000000
# 78   child  ...       False     Child            3        9.666667
# 183  child  ...       False     Child            4        9.750000
# 193  child  ...       False     Child            3        8.666667
# 226    man  ...       False     Adult            1       10.500000
# 288    man  ...       False     Adult            1       13.000000
# 340  child  ...       False     Child            3        8.666667
# 407  child  ...       False     Child            3        6.250000
# 543    man  ...       False     Adult            2       13.000000
# 547    man  ...       False     Adult            1       13.862500
# 549  child  ...       False     Child            3       12.250000
# 570    man  ...        True    Senior            1       10.500000
# 673    man  ...       False     Adult            1       13.000000
# 755  child  ...       False     Child            3        4.833333
# 827  child  ...       False     Child            3       12.334733
# 831  child  ...       False     Child            3        6.250000
#
#      sex_encoded  class_num  survived_bool name_length  title  log_fare
# 17             0          2           True           3    man  2.639057
# 21             0          2           True           3    man  2.639057
# 78             0          2           True           5  child  3.401197
# 183            0          2           True           5  child  3.688879
# 193            0          2           True           5  child  3.295837
# 226            0          2           True           3    man  2.442347
# 288            0          2           True           3    man  2.639057
# 340            0          2           True           5  child  3.295837
# 407            0          2           True           5  child  2.983153
# 543            0          2           True           3    man  3.295837
# 547            0          2           True           3    man  2.698841
# 549            0          2           True           5  child  3.630985
# 570            0          2           True           3    man  2.442347
# 673            0          2           True           3    man  2.639057
# 755            0          2           True           5  child  2.740840
# 827            0          2           True           5  child  3.637697
# 831            0          2           True           5  child  2.983153
#
# [17 rows x 26 columns]

# %% [markdown]
# #### Exporting and Final Tweaks

# %%
#  Save to CSV
df.to_csv('titanic_clean.csv', index=False)

# %%
#  Save to Excel
df.to_excel('titanic_clean.xlsx', index=False)

# %%
#  Save to JSON
df.to_json('titanic_clean.json')

# %%
#  Rename 'fare' to 'ticket_fare'
df.rename(columns={'fare': 'ticket_fare'}, inplace=True)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch  ticket_fare embarked  class  \
# 0         0       3    male  22.0      1      0       7.2500        S  Third
# 1         1       1  female  38.0      1      0      71.2833        C  First
# 2         1       3  female  26.0      0      0       7.9250        S  Third
# 3         1       1  female  35.0      1      0      53.1000        S  First
# 4         0       3    male  35.0      0      0       8.0500        S  Third
#
#      who  ...  is_elderly age_group total_people fare_per_person  sex_encoded  \
# 0    man  ...       False     Adult            2         3.62500            0
# 1  woman  ...       False     Adult            2        35.64165            1
# 2  woman  ...       False     Adult            1         7.92500            1
# 3  woman  ...       False     Adult            2        26.55000            1
# 4    man  ...       False     Adult            1         8.05000            0
#
#    class_num  survived_bool name_length  title  log_fare
# 0          3          False           3    man  2.110213
# 1          1           True           5  woman  4.280593
# 2          3           True           5  woman  2.188856
# 3          1           True           5  woman  3.990834
# 4          3          False           3    man  2.202765
#
# [5 rows x 26 columns]

# %%
#  Create family size
df['family_size'] = df['sibsp'] + df['parch']

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch  ticket_fare embarked  \
# 0           0       3    male  22.0      1      0       7.2500        S
# 1           1       1  female  38.0      1      0      71.2833        C
# 2           1       3  female  26.0      0      0       7.9250        S
# 3           1       1  female  35.0      1      0      53.1000        S
# 4           0       3    male  35.0      0      0       8.0500        S
# ..        ...     ...     ...   ...    ...    ...          ...      ...
# 886         0       2    male  27.0      0      0      13.0000        S
# 887         1       1  female  19.0      0      0      30.0000        S
# 888         0       3  female  28.0      1      2      23.4500        S
# 889         1       1    male  26.0      0      0      30.0000        C
# 890         0       3    male  32.0      0      0       7.7500        Q
#
#       class    who  ...  age_group total_people fare_per_person sex_encoded  \
# 0     Third    man  ...      Adult            2         3.62500           0
# 1     First  woman  ...      Adult            2        35.64165           1
# 2     Third  woman  ...      Adult            1         7.92500           1
# 3     First  woman  ...      Adult            2        26.55000           1
# 4     Third    man  ...      Adult            1         8.05000           0
# ..      ...    ...  ...        ...          ...             ...         ...
# 886  Second    man  ...      Adult            1        13.00000           0
# 887   First  woman  ...      Adult            1        30.00000           1
# 888   Third  woman  ...      Adult            4         5.86250           1
# 889   First    man  ...      Adult            1        30.00000           0
# 890   Third    man  ...      Adult            1         7.75000           0
#
#      class_num  survived_bool  name_length  title  log_fare  family_size
# 0            3          False            3    man  2.110213            1
# 1            1           True            5  woman  4.280593            1
# 2            3           True            5  woman  2.188856            0
# 3            1           True            5  woman  3.990834            1
# 4            3          False            3    man  2.202765            0
# ..         ...            ...          ...    ...       ...          ...
# 886          2          False            3    man  2.639057            0
# 887          1           True            5  woman  3.433987            0
# 888          3          False            5  woman  3.196630            3
# 889          1           True            3    man  3.433987            0
# 890          3          False            3    man  2.169054            0
#
# [891 rows x 27 columns]

# %%
#  Boolean: is_alone
df['is_alone'] = df['family_size'] == 0

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch  ticket_fare embarked  \
# 0           0       3    male  22.0      1      0       7.2500        S
# 1           1       1  female  38.0      1      0      71.2833        C
# 2           1       3  female  26.0      0      0       7.9250        S
# 3           1       1  female  35.0      1      0      53.1000        S
# 4           0       3    male  35.0      0      0       8.0500        S
# ..        ...     ...     ...   ...    ...    ...          ...      ...
# 886         0       2    male  27.0      0      0      13.0000        S
# 887         1       1  female  19.0      0      0      30.0000        S
# 888         0       3  female  28.0      1      2      23.4500        S
# 889         1       1    male  26.0      0      0      30.0000        C
# 890         0       3    male  32.0      0      0       7.7500        Q
#
#       class    who  ...  total_people fare_per_person sex_encoded class_num  \
# 0     Third    man  ...             2         3.62500           0         3
# 1     First  woman  ...             2        35.64165           1         1
# 2     Third  woman  ...             1         7.92500           1         3
# 3     First  woman  ...             2        26.55000           1         1
# 4     Third    man  ...             1         8.05000           0         3
# ..      ...    ...  ...           ...             ...         ...       ...
# 886  Second    man  ...             1        13.00000           0         2
# 887   First  woman  ...             1        30.00000           1         1
# 888   Third  woman  ...             4         5.86250           1         3
# 889   First    man  ...             1        30.00000           0         1
# 890   Third    man  ...             1         7.75000           0         3
#
#      survived_bool  name_length  title  log_fare  family_size  is_alone
# 0            False            3    man  2.110213            1     False
# 1             True            5  woman  4.280593            1     False
# 2             True            5  woman  2.188856            0      True
# 3             True            5  woman  3.990834            1     False
# 4            False            3    man  2.202765            0      True
# ..             ...          ...    ...       ...          ...       ...
# 886          False            3    man  2.639057            0      True
# 887           True            5  woman  3.433987            0      True
# 888          False            5  woman  3.196630            3     False
# 889           True            3    man  3.433987            0      True
# 890          False            3    man  2.169054            0      True
#
# [891 rows x 28 columns]

# %%
#  Map embarked to full names
df['embarked_full'] = df['embarked'].map({'S': 'Southampton', 'C': 'Cherbourg', 'Q': 'Queenstown'})

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch  ticket_fare embarked  \
# 0           0       3    male  22.0      1      0       7.2500        S
# 1           1       1  female  38.0      1      0      71.2833        C
# 2           1       3  female  26.0      0      0       7.9250        S
# 3           1       1  female  35.0      1      0      53.1000        S
# 4           0       3    male  35.0      0      0       8.0500        S
# ..        ...     ...     ...   ...    ...    ...          ...      ...
# 886         0       2    male  27.0      0      0      13.0000        S
# 887         1       1  female  19.0      0      0      30.0000        S
# 888         0       3  female  28.0      1      2      23.4500        S
# 889         1       1    male  26.0      0      0      30.0000        C
# 890         0       3    male  32.0      0      0       7.7500        Q
#
#       class    who  ...  fare_per_person sex_encoded class_num survived_bool  \
# 0     Third    man  ...          3.62500           0         3         False
# 1     First  woman  ...         35.64165           1         1          True
# 2     Third  woman  ...          7.92500           1         3          True
# 3     First  woman  ...         26.55000           1         1          True
# 4     Third    man  ...          8.05000           0         3         False
# ..      ...    ...  ...              ...         ...       ...           ...
# 886  Second    man  ...         13.00000           0         2         False
# 887   First  woman  ...         30.00000           1         1          True
# 888   Third  woman  ...          5.86250           1         3         False
# 889   First    man  ...         30.00000           0         1          True
# 890   Third    man  ...          7.75000           0         3         False
#
#      name_length  title  log_fare family_size  is_alone  embarked_full
# 0              3    man  2.110213           1     False    Southampton
# 1              5  woman  4.280593           1     False      Cherbourg
# 2              5  woman  2.188856           0      True    Southampton
# 3              5  woman  3.990834           1     False    Southampton
# 4              3    man  2.202765           0      True    Southampton
# ..           ...    ...       ...         ...       ...            ...
# 886            3    man  2.639057           0      True    Southampton
# 887            5  woman  3.433987           0      True    Southampton
# 888            5  woman  3.196630           3     False    Southampton
# 889            3    man  3.433987           0      True      Cherbourg
# 890            3    man  2.169054           0      True     Queenstown
#
# [891 rows x 29 columns]

# %%
# 99. Fare rounded
df['fare_rounded'] = df['ticket_fare'].round(2)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch  ticket_fare embarked  \
# 0           0       3    male  22.0      1      0       7.2500        S
# 1           1       1  female  38.0      1      0      71.2833        C
# 2           1       3  female  26.0      0      0       7.9250        S
# 3           1       1  female  35.0      1      0      53.1000        S
# 4           0       3    male  35.0      0      0       8.0500        S
# ..        ...     ...     ...   ...    ...    ...          ...      ...
# 886         0       2    male  27.0      0      0      13.0000        S
# 887         1       1  female  19.0      0      0      30.0000        S
# 888         0       3  female  28.0      1      2      23.4500        S
# 889         1       1    male  26.0      0      0      30.0000        C
# 890         0       3    male  32.0      0      0       7.7500        Q
#
#       class    who  ...  sex_encoded class_num survived_bool name_length  \
# 0     Third    man  ...            0         3         False           3
# 1     First  woman  ...            1         1          True           5
# 2     Third  woman  ...            1         3          True           5
# 3     First  woman  ...            1         1          True           5
# 4     Third    man  ...            0         3         False           3
# ..      ...    ...  ...          ...       ...           ...         ...
# 886  Second    man  ...            0         2         False           3
# 887   First  woman  ...            1         1          True           5
# 888   Third  woman  ...            1         3         False           5
# 889   First    man  ...            0         1          True           3
# 890   Third    man  ...            0         3         False           3
#
#      title  log_fare  family_size is_alone  embarked_full  fare_rounded
# 0      man  2.110213            1    False    Southampton          7.25
# 1    woman  4.280593            1    False      Cherbourg         71.28
# 2    woman  2.188856            0     True    Southampton          7.92
# 3    woman  3.990834            1    False    Southampton         53.10
# 4      man  2.202765            0     True    Southampton          8.05
# ..     ...       ...          ...      ...            ...           ...
# 886    man  2.639057            0     True    Southampton         13.00
# 887  woman  3.433987            0     True    Southampton         30.00
# 888  woman  3.196630            3    False    Southampton         23.45
# 889    man  3.433987            0     True      Cherbourg         30.00
# 890    man  2.169054            0     True     Queenstown          7.75
#
# [891 rows x 30 columns]

# %%
df.to_csv('titanic_updated.csv', index=False)
df.to_excel('titanic_updated.xlsx', index=False)

# %%
# 100. Drop all rows with missing age or fare
df.dropna(subset=['age', 'ticket_fare'])
# Out:
#      survived  pclass     sex   age  sibsp  parch  ticket_fare embarked  \
# 0           0       3    male  22.0      1      0       7.2500        S
# 1           1       1  female  38.0      1      0      71.2833        C
# 2           1       3  female  26.0      0      0       7.9250        S
# 3           1       1  female  35.0      1      0      53.1000        S
# 4           0       3    male  35.0      0      0       8.0500        S
# ..        ...     ...     ...   ...    ...    ...          ...      ...
# 886         0       2    male  27.0      0      0      13.0000        S
# 887         1       1  female  19.0      0      0      30.0000        S
# 888         0       3  female  28.0      1      2      23.4500        S
# 889         1       1    male  26.0      0      0      30.0000        C
# 890         0       3    male  32.0      0      0       7.7500        Q
#
#       class    who  ...  sex_encoded class_num survived_bool name_length  \
# 0     Third    man  ...            0         3         False           3
# 1     First  woman  ...            1         1          True           5
# 2     Third  woman  ...            1         3          True           5
# 3     First  woman  ...            1         1          True           5
# 4     Third    man  ...            0         3         False           3
# ..      ...    ...  ...          ...       ...           ...         ...
# 886  Second    man  ...            0         2         False           3
# 887   First  woman  ...            1         1          True           5
# 888   Third  woman  ...            1         3         False           5
# 889   First    man  ...            0         1          True           3
# 890   Third    man  ...            0         3         False           3
#
#      title  log_fare  family_size is_alone  embarked_full  fare_rounded
# 0      man  2.110213            1    False    Southampton          7.25
# 1    woman  4.280593            1    False      Cherbourg         71.28
# 2    woman  2.188856            0     True    Southampton          7.92
# 3    woman  3.990834            1    False    Southampton         53.10
# 4      man  2.202765            0     True    Southampton          8.05
# ..     ...       ...          ...      ...            ...           ...
# 886    man  2.639057            0     True    Southampton         13.00
# 887  woman  3.433987            0     True    Southampton         30.00
# 888  woman  3.196630            3    False    Southampton         23.45
# 889    man  3.433987            0     True      Cherbourg         30.00
# 890    man  2.169054            0     True     Queenstown          7.75
#
# [891 rows x 30 columns]
